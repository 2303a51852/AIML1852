# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51852/AIML1852/blob/main/Genetic%20Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Number of individuals in each generation
POPULATION_SIZE = 100

# Valid genes
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOP
QRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}'''

# Target string to be generated
TARGET = "I love GeeksforGeeks"

class Individual:
    '''
    Class representing individual in population
    '''
    def __init__(self, chromosome):
        self.chromosome = chromosome
        self.fitness = self.cal_fitness()

    @classmethod
    def mutated_genes(cls):
        '''
        Create random genes for mutation
        '''
        return random.choice(GENES)

    @classmethod
    def create_gnome(cls):
        '''
        Create chromosome or string of genes
        '''
        return [cls.mutated_genes() for _ in range(len(TARGET))]

    def mate(self, par2):
        '''
        Perform mating and produce new offspring
        '''
        child_chromosome = []
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):
            prob = random.random()
            if prob < 0.45:
                child_chromosome.append(gp1)
            elif prob < 0.90:
                child_chromosome.append(gp2)
            else:
                child_chromosome.append(self.mutated_genes())
        return Individual(child_chromosome)

    def cal_fitness(self):
        '''
        Calculate fitness score, it is the number of
        characters in string which differ from target
        string.
        '''
        return sum(1 for gs, gt in zip(self.chromosome, TARGET) if gs != gt)

def main():
    generation = 1
    found = False
    population = [Individual(Individual.create_gnome()) for _ in range(POPULATION_SIZE)]

    while not found:
        population = sorted(population, key=lambda x: x.fitness)

        if population[0].fitness <= 0:
            found = True
            break

        new_generation = []

        # Elitism, 10% of fittest population goes to the next generation
        s = int((10 * POPULATION_SIZE) / 100)
        new_generation.extend(population[:s])

        # From 90% of fittest population, Individuals will mate to produce offspring
        s = int((90 * POPULATION_SIZE) / 100)
        for _ in range(s):
            parent1 = random.choice(population[:50])
            parent2 = random.choice(population[:50])
            child = parent1.mate(parent2)
            new_generation.append(child)

        population = new_generation

        print(f"Generation: {generation}\tString: {''.join(population[0].chromosome)}\tFitness: {population[0].fitness}")

        generation += 1

    print(f"Generation: {generation}\tString: {''.join(population[0].chromosome)}\tFitness: {population[0].fitness}")

if __name__ == '__main__':
    main()
# Out:
# Generation: 1	String: ?L};Te i%OYic A1X_G
# 	Fitness: 18
# Generation: 2	String: ?L};Te i%OYic A1X_G
# 	Fitness: 18
# Generation: 3	String: K7eovmkM:Pm7uFrJ!!jj	Fitness: 17
# Generation: 4	String: b!Yc9e &;CmQfAiJXa s	Fitness: 16
# Generation: 5	String: b!Yc9e &;CmQfAiJXa s	Fitness: 16
# Generation: 6	String: K7eovuzMfP87
# orG9Rjj	Fitness: 15
# Generation: 7	String: ISeo7e M{Z&7/orndR4#	Fitness: 14
# Generation: 8	String: p :;vl ?)_pqfoiGbelz	Fitness: 13
# Generation: 9	String: ILhjve i&fkHf$r_3e s	Fitness: 11
# Generation: 10	String: ILhjve i&fkHf$r_3e s	Fitness: 11
# Generation: 11	String: I u;v} &2C&(forGSe}s	Fitness: 10
# Generation: 12	String: I u;v} &2C&(forGSe}s	Fitness: 10
# Generation: 13	String: I!9ove hi3k:%orGdgks	Fitness: 9
# Generation: 14	String: I!9ove hi3k:%orGdgks	Fitness: 9
# Generation: 15	String: I!9ove hi3k:%orGdgks	Fitness: 9
# Generation: 16	String: IJtove 1_]ksforxdekE	Fitness: 8
# Generation: 17	String: Ig,ove QiC%sforGdeks	Fitness: 7
# Generation: 18	String: Ig,ove QiC%sforGdeks	Fitness: 7
# Generation: 19	String: Ig,ove Qi]ksforGKeks	Fitness: 6
# Generation: 20	String: Ig,ove Qi]ksforGKeks	Fitness: 6
# Generation: 21	String: Ig,ove Qi]ksforGKeks	Fitness: 6
# Generation: 22	String: Ig,ove Qi]ksforGKeks	Fitness: 6
# Generation: 23	String: Ig,ove Qi]ksforGKeks	Fitness: 6
# Generation: 24	String: I ,ove &e3ssforGdeks	Fitness: 5
# Generation: 25	String: I ,ove &e3ssforGdeks	Fitness: 5
# Generation: 26	String: I ,ove &e3ssforGdeks	Fitness: 5
# Generation: 27	String: I(kove GieksforGSeks	Fitness: 4
# Generation: 28	String: I(kove GieksforGSeks	Fitness: 4
# Generation: 29	String: I(kove GieksforGSeks	Fitness: 4
# Generation: 30	String: I(kove GieksforGSeks	Fitness: 4
# Generation: 31	String: I 4ove G.eksforGSeks	Fitness: 3
# Generation: 32	String: I 4ove G.eksforGSeks	Fitness: 3
# Generation: 33	String: I 4ove G.eksforGSeks	Fitness: 3
# Generation: 34	String: I 4ove G.eksforGSeks	Fitness: 3
# Generation: 35	String: I 4ove G.eksforGSeks	Fitness: 3
# Generation: 36	String: I zove GeeksforG6eks	Fitness: 2
# Generation: 37	String: I zove GeeksforG6eks	Fitness: 2
# Generation: 38	String: I zove GeeksforG6eks	Fitness: 2
# Generation: 39	String: I zove GeeksforG6eks	Fitness: 2
# Generation: 40	String: I zove GeeksforG6eks	Fitness: 2
# Generation: 41	String: I zove GeeksforG6eks	Fitness: 2
# Generation: 42	String: I zove GeeksforG6eks	Fitness: 2
# Generation: 43	String: I zove GeeksforG6eks	Fitness: 2
# Generation: 44	String: I zove GeeksforG6eks	Fitness: 2
# Generation: 45	String: I zove GeeksforG6eks	Fitness: 2
# Generation: 46	String: I zove GeeksforG6eks	Fitness: 2
# Generation: 47	String: I zove GeeksforG6eks	Fitness: 2
# Generation: 48	String: I zove GeeksforG6eks	Fitness: 2
# Generation: 49	String: I zove GeeksforG6eks	Fitness: 2
# Generation: 50	String: I zove GeeksforG6eks	Fitness: 2
# Generation: 51	String: I zove GeeksforG6eks	Fitness: 2
# Generation: 52	String: I zove GeeksforG6eks	Fitness: 2
# Generation: 53	String: I zove GeeksforG6eks	Fitness: 2
# Generation: 54	String: I zove GeeksforG6eks	Fitness: 2
# Generation: 55	String: I zove GeeksforG6eks	Fitness: 2
# Generation: 56	String: I zove GeeksforG6eks	Fitness: 2
# Generation: 57	String: I zove GeeksforG6eks	Fitness: 2
# Generation: 58	String: I zove GeeksforG6eks	Fitness: 2
